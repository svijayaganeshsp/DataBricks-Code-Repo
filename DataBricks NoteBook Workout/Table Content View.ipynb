# %% [markdown]
# # Heading 1

# %%
# %sql
Select current_database()

# %% [markdown]
# ## Heading 2

# %% [markdown]
# ### SQL with Pyspark

# %%
# %sql
CREATE TABLE if not exists default.cityes1(Id int,Nm VARCHAR(20));
Insert into default.cityes1(Id,Nm) VALUES (1,'NY'),(2,'LA'),(3,'SF');
     
SELECT * FROM default.cityes1

# %%
display(spark.sql("SELECT * FROM default.cityes1"))

# %%
# %sql
show create table default.cityes1

# %% [markdown]
# ### CSV Data Load

# %%
# %py

dbutils.fs.cp(
    "https://public.tableau.com/app/sample-data/mobile_os_usage.csv",
    "dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"
)
df = spark.read.format("csv") \
    .option("inferSchema", "true") \
    .option("header", "true") \
    .option("sep", ",") \
    .load("dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")

display(df)

# %%
import requests
response = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
dbutils.fs.put("dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv", response.text, overwrite=True)

# %%
# %fs
ls dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
# %fs head dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %% [markdown]
# ### CSV file load from CSV Data Load

# %%
notebook_path = "https://dbc-86135934-e538.cloud.databricks.com/editor/notebooks/4178496745787198?o=2581770762539356#command/4687104088733137"
timeout_seconds = 600

result = dbutils.notebook.run(
    path=notebook_path,
    timeout_seconds=timeout_seconds
)

print(f"Child notebook returned: {result}")

# %% [markdown]
# ### Linux Command

# %%
# %sh
ls -l

# %%
# %sh
ls /databricks-datasets

# %% [markdown]
# ### Read the datasets from data Bricks

# %%
# %py
display(dbutils.fs.ls("/databricks-datasets/samples/"))

# %%
 # %sql
SELECT * FROM read_files(
  '/databricks-datasets/samples/population-vs-price/data_geo.csv',
  format => 'csv',
  header => true,
  mode => 'FAILFAST'
) LIMIT 10;
