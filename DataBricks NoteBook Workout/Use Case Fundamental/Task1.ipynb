# %% [markdown]
# #My First DataBricks Code Start
# - ##Sub Taks One
# - ##Sub Task Two

# %% [markdown]
# $${\color{blue}\textbf{VIJAY}}$$
# <span style="color:green">VIJAY</span>
# **Vijaya Ganesh S (Bold)**
# ### _W47 Team Photo_(Italic)
# ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)
