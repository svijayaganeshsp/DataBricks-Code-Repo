# %%
# %sql
CREATE CONNECTION gcp_mysql_conn_we47
TYPE mysql
OPTIONS (
  host '34.123.166.158',
  port '3306',
  user 'devuser',
  password 'Inceptez@123'
);

# %%
# %sql
CREATE FOREIGN CATALOG gcp_mysql_fc_we471
USING CONNECTION gcp_mysql_conn_we47;

# %%
# %sql
DESCRIBE CONNECTION gcp_mysql_conn_we47;

# %%
# %sql
show catalogs;

# %%
# %sql
select * from gcp_mysql_fc_we471.logistics.shipments1;

# %%
# %sql
--Historical (Onetime) load
CREATE TABLE IF NOT EXISTS catalog1_we47.schema_we47.shipments1
USING DELTA
AS SELECT
  shipment_id,
  first_name,
  last_name,
  age,
  role,
  updated_at
FROM gcp_mysql_fc_we471.logistics.shipments1;

# %%
# %sql
Select * from catalog1_we47.schema_we47.shipments1

# %%
# %sql
INSERT INTO catalog1_we47.schema_we47.shipments1
SELECT
  shipment_id,
  first_name,
  last_name,
  age,
  role,
  updated_at
FROM gcp_mysql_fc_we471.logistics.shipments1

# %%
# %sql
Select * FROM  catalog1_we47.schema1_we47.shipment1_bronze2
